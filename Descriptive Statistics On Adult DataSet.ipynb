# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file=open('IDSgithub/files/ch03/adult.data','r')
def chr_int(a):
    if a.isdigit(): return int(a)
    else: return 0
data=[]
for line in file:
    data1=line.split(', ')
    if len(data1)==15:
        data.append([chr_int(data1[0]),data1[1],chr_int(data1[2]),data1[3],chr_int(data1[4]),data1[5],data1[6],data1[7],data1[8],data1[9],chr_int(data1[10]),chr_int(data1[11]),chr_int(data1[12]),data1[13],data1[14]])

# %%
print (data[1:2])
# Out:
# [[50, 'Self-emp-not-inc', 83311, 'Bachelors', 13, 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male', 0, 0, 13, 'United-States', '<=50K\n']]

# %%
df=pd.DataFrame(data)
df.columns=['age','type_employer','fnlwgt','education','education_num','marital','occupation','relationship','race','sex','capital_gain','capital_loss','hr_per_Week','country','income']

# %%
df.shape
# Out:
# (32561, 15)

# %%
counts=df.groupby('country').size()
counts
# Out:
# country
# ?                               583
# Cambodia                         19
# Canada                          121
# China                            75
# Columbia                         59
# Cuba                             95
# Dominican-Republic               70
# Ecuador                          28
# El-Salvador                     106
# England                          90
# France                           29
# Germany                         137
# Greece                           29
# Guatemala                        64
# Haiti                            44
# Holand-Netherlands                1
# Honduras                         13
# Hong                             20
# Hungary                          13
# India                           100
# Iran                             43
# Ireland                          24
# Italy                            73
# Jamaica                          81
# Japan                            62
# Laos                             18
# ...

# %%
ml=df[(df.sex=='Male')]
ml
# Out:
#        age     type_employer  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 13      32           Private  205019    Assoc-acdm             12
# 14      40           Private  121772     Assoc-voc             11
# 15      34           Private  245487       7th-8th              4
# 16      25  Self-emp-not-inc  176756       HS-grad              9
# 17      32           Private  186824       HS-grad              9
# ...

# %%
fm=df[(df.sex=='Female')]
fm
# Out:
#        age     type_employer  fnlwgt     education  education_num  \
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 8       31           Private   45781       Masters             14
# 12      23           Private  122272     Bachelors             13
# 19      43  Self-emp-not-inc  292175       Masters             14
# 21      54           Private  302146       HS-grad              9
# 24      59           Private  109015       HS-grad              9
# 37      19           Private  544091       HS-grad              9
# 43      49           Private   94638       HS-grad              9
# 47      44           Private  128354       Masters             14
# 50      25           Private   32275  Some-college             10
# 51      18           Private  226956       HS-grad              9
# ...

# %%
ml1=df[(df.sex=='Male')&(df.income=='>50K\n')]
ml1
# Out:
#        age     type_employer  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# ...

# %%
fm1=df[(df.sex=='Female')&(df.income=='>50K\n')]
fm1
# Out:
#        age     type_employer  fnlwgt     education  education_num  \
# 8       31           Private   45781       Masters             14
# 19      43  Self-emp-not-inc  292175       Masters             14
# 52      47           Private   51835   Prof-school             15
# 67      53           Private  169846       HS-grad              9
# 84      44           Private  343591       HS-grad              9
# 89      43       Federal-gov  410867     Doctorate             16
# 125     47           Private  287828     Bachelors             13
# 143     45           Private  196584     Assoc-voc             11
# 197     40       Federal-gov   56795       Masters             14
# 208     58      Self-emp-inc  210563       HS-grad              9
# 250     41           Private  112763   Prof-school             15
# 269     33           Private  222205       HS-grad              9
# 279     24           Private  279472  Some-college             10
# ...

# %%
df1=df[(df.income=='>50K\n')]
print('The rate of people with high income is: ',int(len(df1)/int(len(df))*100), '%.')
print('The rate of men with high income is: ',int(len(ml1)/int(len(ml))*100), '%.')
print('The rate of women with high income is: ',int(len(fm1)/int(len(fm))*100), '%.')
# Out:
# The rate of people with high income is:  24 %.
# The rate of men with high income is:  30 %.
# The rate of women with high income is:  10 %.

# %%
print('The average age of men is: ',ml['age'].mean())
print('The average age of women is: ',fm['age'].mean())
print('The average age of high-income men is: ',ml1['age'].mean())
print('The average age of high-income women is: ',fm1['age'].mean())
# Out:
# The average age of men is:  39.43354749885268
# The average age of women is:  36.85823043357163
# The average age of high-income men is:  44.62578805163614
# The average age of high-income women is:  42.125530110262936

# %%
ml_me=ml['age'].mean()
ml_var=ml['age'].var()
ml_std=ml['age'].std()
fm_me=fm['age'].mean()
fm_var=fm['age'].var()
fm_std=fm['age'].std()
print('Statistics of age for men: Mean: ', ml_me, ',Variance: ', ml_var, ', Standard Deviation: ', ml_std)
print('Statistics of age for women: Mean: ', fm_me, ', Variance: ', fm_var, ', Standard Deviation: ', fm_std)
# Out:
# Statistics of age for men: Mean:  39.43354749885268 ,Variance:  178.77375174530096 , Standard Deviation:  13.37063019252649
# Statistics of age for women: Mean:  36.85823043357163 , Variance:  196.3837063948037 , Standard Deviation:  14.01369709943824

# %%
ml_median=ml['age'].median()
fm_median=fm['age'].median()
print("Median age per men and women is: ", ml_median, "&", fm_median)
ml1_median=ml1['age'].median()
fm1_median=fm1['age'].median()
print("Median age per men and women with high income is: ", ml1_median, "&", fm1_median)
# Out:
# Median age per men and women is:  38.0 & 35.0
# Median age per men and women with high income is:  44.0 & 41.0

# %%
ml_age=ml['age']
ml_age.hist(density=0,histtype='stepfilled',bins=20)
fm_age=fm['age']
fm_age.hist(density=0,histtype='stepfilled',bins=10)

# %%
ml_age=ml['age']
ml_age.hist(density=0,histtype='stepfilled',bins=20)
fm_age=fm['age']
fm_age.hist(density=0,histtype='stepfilled',bins=10)

# %%
import seaborn as sns
ml_age.hist(density=0,histtype='stepfilled',alpha=.5,bins=20)
fm_age.hist(density=0,histtype='stepfilled',alpha=.5,color=sns.desaturate("indianred",.75),bins=10)

# %%
import seaborn as sns
ml_age.hist(density=1,histtype='stepfilled',alpha=.5,bins=20)
fm_age.hist(density=1,histtype='stepfilled',alpha=.5,color=sns.desaturate("indianred",.75),bins=10)

# %%
ml_age=ml['age']
ml_age.hist(density=0,histtype='stepfilled',bins=20)

# %%
fm_age=fm['age']
fm_age.hist(density=0,histtype='stepfilled',bins=10)

# %%
import seaborn as sns
fm_age.hist(density=0,histtype='stepfilled',alpha=.5,bins=20)
ml_age.hist(density=0,histtype='stepfilled',alpha=.5,color=sns.desaturate("indianred",.75),bins=10)

# %%
fm_age.hist(density=1,histtype='stepfilled',alpha=.5,bins=20)
ml_age.hist(density=1,histtype='stepfilled',alpha=.5,bins=10,color=sns.desaturate("indianred",.75))

# %%
ml_age.hist(density=1,histtype='step',cumulative=True,linewidth=3.5,bins=20)
fm_age.hist(density=1,histtype='step',cumulative=True,linewidth=3.5,bins=20,color=sns.desaturate("indianred",.75))

# %%
df2=df.drop(df.index[(df.income=='>50K\n')&(df['age']>df['age'].median()+35)&(df['age']>df['age'].median()-15)])
ml1_age=ml1['age']
fm1_age=fm1['age']
ml2_age=ml1_age.drop(ml1_age.index[(ml1_age>df['age'].median()+35)&(ml1_age>df['age'].median()-15)])
fm2_age=fm1_age.drop(fm1_age.index[(fm1_age>df['age'].median()+35)&(fm1_age>df['age'].median()-15)])

# %%
mu2ml=ml2_age.mean()
std2ml=ml2_age.std()
md2ml=ml2_age.median()
mu2fm=fm2_age.mean()
std2fm=fm2_age.std()
md2fm=fm2_age.median()
print("Men Statistics:")
print("Mean: ",mu2ml)
print("Std: ",std2ml)
print("Min: ",ml2_age.min())
print("Max: ",ml2_age.max())
print("Women Statistics:")
print("Mean: ",mu2fm)
print("Std: ",std2fm)
print("Min: ",fm2_age.min())
print("Max: ",fm2_age.max())
# Out:
# Men Statistics:
# Mean:  44.317982123920615
# Std:  10.019749857171412
# Min:  19
# Max:  72
# Women Statistics:
# Mean:  41.877028181041844
# Std:  10.036441807343714
# Min:  19
# Max:  72

# %%
plt.figure(figsize=(13.4,5))
df.age[(df.income=='>50K\n')].plot(alpha=.25,color='blue')
df2.age[(df.income=='>50K\n')].plot(alpha=.45,color='red')

# %%
print('The mean difference with outliers is: %4.2f.'%(ml_age.mean()-fm_age.mean()))
print('The mean difference without outliers is: %4.2f.'%(ml2_age.mean()-fm2_age.mean()))
# Out:
# The mean difference with outliers is: 2.58.
# The mean difference without outliers is: 2.44.

# %%
countx,divisionx=np.histogram(ml2_age,density=True)
county,divisiony=np.histogram(fm2_age,density=True)
val=[(divisionx[i]+divisionx[i+1])/2 for i in range(len(divisionx)-1)]
plt.plot(val,countx-county,'o-')

# %%
def skewness(x):
    res=0
    m=x.mean()
    s=x.std()
    for i in x:
        res +=(i-m)*(i-m)*(i-m)
    res/=(len(x)*s*s*s)
    return res
print("Skewness of the male population = ", skewness(ml2_age))
print("Skewness of the female population = ", skewness(fm2_age))
# Out:
# Skewness of the male population =  0.2664443838432819
# Skewness of the female population =  0.38633352491285977

# %%
def pearson(x):
    return 3*(x.mean()-x.median())*x.std()
print("Pearson's coefficient of the male population = ",pearson(ml2_age))
print("Pearson's coefficient of the female population = ",pearson(fm2_age))
# Out:
# Pearson's coefficient of the male population =  9.55830402220993
# Pearson's coefficient of the female population =  26.40672690728092

# %%
from scipy.stats import norm
x1=np.random.normal(-1,0.5,15)
x2=np.random.normal(6,1,10)
y=np.r_[x1,x2]
x=np.linspace(min(y),max(y),100)
s=0.4
kernels=np.transpose([norm.pdf(x,yi,s) for yi in y])
plt.plot(x,kernels,'k:')
plt.plot(x,kernels.sum(1),'r')
plt.plot(y,np.zeros(len(y)),'bo',ms=10)

# %%
from scipy.stats import kde
density=kde.gaussian_kde(y)
xgrid=np.linspace(x.min(),x.max(),200)
plt.hist(y,bins=28,density=True)
plt.plot(xgrid,density(xgrid),'r-')

# %%
NTs=200
mu=0.0
var=1.0
err=0.0
NPs=1000
for i in range(NTs):
    x=np.random.normal(mu,var,NPs)
    err+=(x.mean()-mu)**2
print('MSE: ',err/NTs)
# Out:
# MSE:  0.001019711094643194
